# %% [markdown]
# Pandas Series
#
# A Series is one dimenisonal labelled array capable of holding any data type. The axis labels are collectively called the index
#
# Creating Series
#
# There are multiple ways to create a pandas series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# pd.Series(my_list,index=labels)

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
 pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a DataFrame

# %%
data = {
    'Name': ['John','Anna','Peter','Linda'],
    'Age': [28,34,29,42],
    'City': ['New York','Paris','Berlin','London'],
    'Salart': [65000,70000,62000,85000]
}
pd.DataFrame(data)
# Out:
#     Name  Age      City  Salart
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',70000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns = columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2["Designation"] = ["Doctor", "Engineer", "Doctor","Engineer"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
df2.drop(["Age","Salary"],axis=1) ####IMPORTANT
# Out:
#     Name      City Designation
# 0   John  New York      Doctor
# 1   Anna     Paris    Engineer
# 2  Peter    Berlin      Doctor
# 3  Linda    London    Engineer

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 2  Peter   29  Berlin   62000      Doctor
# 3  Linda   42  London   85000    Engineer

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %% [markdown]
# Selection and Indexing of Columns

# %% [markdown]
# Creating a new column

# %% [markdown]
# Removing Columns

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
df2.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# Designation      Doctor
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000      Doctor
# 1  Anna   34     Paris   70000    Engineer

# %%
df2.iloc[3]
# Out:
# Name              Linda
# Age                  42
# City             London
# Salary            85000
# Designation    Engineer
# Name: 3, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000      Doctor
# 1  Anna   34     Paris   70000    Engineer

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %% [markdown]
# Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
#Print whose age is above 30

df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 3  Linda   42  London   85000    Engineer

# %%
#Age above 30 and Paris
df2[(df2["Age"] > 30) & (df2["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary Designation
# 1  Anna   34  Paris   70000    Engineer
